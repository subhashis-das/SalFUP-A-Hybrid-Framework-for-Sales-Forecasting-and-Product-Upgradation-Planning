# %% [markdown]
# ## Instructions
#
# 1. **Run Each Cell Sequentially**
#    Execute the cells one by one in order except the dataset cells. Do **not** skip any cells.
#
# 2. **Save Results and Data After Each Cell**
#    Each cell should save its output, plots, and any generated data to the output folder before moving to the next cell.
#
# 3. **Clean Output Folders When Re-running**
#    If you want to re-run a cell or a section of the notebook, make sure to **delete the previous output folders** in the directory first. This avoids conflicts or overwriting old results.

# %% [markdown]
# ## Install Dependencies

# %%
# !pip install swifter
# !pip install pipeline
# !pip install vaderSentiment contractions pyspellchecker
# !pip install shap
# !pip install tensorflow
# !pip install wordcloud
# !pip install transformers
# !pip install spacy
# !pip install nltk
# !pip install torch
# !pip install pmdarima
# !pip install tf_keras
# !python -m spacy download en_core_web_sm

# %%
import os
os.chdir("Journal2Code/")

# %% [markdown]
# ## All Magazine

# %% [markdown]
# ### VADER

# %%
# !python main.py \
  --url "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/review_categories/Magazine_Subscriptions.jsonl.gz" \
  --meta_url "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/meta_categories/meta_Magazine_Subscriptions.jsonl.gz" \
  --useVader "T"

# %% [markdown]
# ## Amazon Fashion (LSTM)

# %% [markdown]
# ### VADER

# %%
# !python main.py \
  --url "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/review_categories/Amazon_Fashion.jsonl.gz" \
  --meta_url "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/meta_categories/meta_Amazon_Fashion.jsonl.gz" \
  --useVader "T"

# %% [markdown]
# ## CellPhoneAndAccessories

# %% [markdown]
# ### VADER

# %%
# !python main.py \
  --url "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/review_categories/Cell_Phones_and_Accessories.jsonl.gz" \
  --meta_url "https://mcauleylab.ucsd.edu/public_datasets/data/amazon_2023/raw/meta_categories/meta_Cell_Phones_and_Accessories.jsonl.gz" \
  --useVader "T"
